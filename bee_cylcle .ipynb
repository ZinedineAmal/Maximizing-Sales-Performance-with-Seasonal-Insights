# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_excel('/content/dataset_bee_cycle.xlsx')
df.head(5)
# Out:
#   order_detail_id order_date  product_id  customer_id  origin_id  quantity  \
# 0       SO43698-1 2016-01-07         346        28389          7         1
# 1       SO43704-1 2016-02-07         351        11005          9         1
# 2       SO43705-1 2016-02-07         344        11011          9         1
# 3       SO43713-1 2016-05-07         310        27601          4         1
# 4       SO43714-1 2016-05-07         311        13591         10         1
#
#    unitprice_rupiah  totalprice_rupiah  totalcost_rupiah  \
# 0          47599860           47599860          26770162
# 1          47249860           47249860          26573322
# 2          47599860           47599860          26770162
# 3          50095780           50095780          30398119
# 4          50095780           50095780          30398119
#
#    shippingprice_rupiah  ... category     customer_name gender maritalstatus  \
# 0               1189997  ...    Bikes  Rachael Martinez      F             S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5953 entries, 0 to 5952
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_detail_id       5953 non-null   object
#  1   order_date            5953 non-null   datetime64[ns]
#  2   product_id            5953 non-null   int64
#  3   customer_id           5953 non-null   int64
#  4   origin_id             5953 non-null   int64
#  5   quantity              5953 non-null   int64
#  6   unitprice_rupiah      5953 non-null   int64
#  7   totalprice_rupiah     5953 non-null   int64
#  8   totalcost_rupiah      5953 non-null   int64
#  9   shippingprice_rupiah  5953 non-null   int64
#  10  product_name          5953 non-null   object
#  11  model_name            5953 non-null   object
#  12  color                 3598 non-null   object
#  13  size_range            2811 non-null   object
#  14  sub_category          5953 non-null   object
# ...

# %%
df_new = ['order_detail_id', 'order_date', 'product_id', 'customer_id', 'quantity', 'totalprice_rupiah', 'shippingprice_rupiah', 'product_name', 'category', 'gender', 'maritalstatus', 'territory_country']

# %%
#buatkan dataframe baru untuk df_new
df_new = df[df_new]
df_new.head(5)
# Out:
#   order_detail_id order_date  product_id  customer_id  quantity  \
# 0       SO43698-1 2016-01-07         346        28389         1
# 1       SO43704-1 2016-02-07         351        11005         1
# 2       SO43705-1 2016-02-07         344        11011         1
# 3       SO43713-1 2016-05-07         310        27601         1
# 4       SO43714-1 2016-05-07         311        13591         1
#
#    totalprice_rupiah  shippingprice_rupiah             product_name category  \
# 0           47599860               1189997  Mountain-100 Silver, 44    Bikes
# 1           47249860               1181247   Mountain-100 Black, 48    Bikes
# 2           47599860               1189997  Mountain-100 Silver, 38    Bikes
# 3           50095780               1252395         Road-150 Red, 62    Bikes
# 4           50095780               1252395         Road-150 Red, 44    Bikes
#
#   gender maritalstatus territory_country
# 0      F             S            France
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5953 entries, 0 to 5952
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_detail_id       5953 non-null   object
#  1   order_date            5953 non-null   datetime64[ns]
#  2   product_id            5953 non-null   int64
#  3   customer_id           5953 non-null   int64
#  4   quantity              5953 non-null   int64
#  5   totalprice_rupiah     5953 non-null   int64
#  6   shippingprice_rupiah  5953 non-null   int64
#  7   product_name          5953 non-null   object
#  8   category              5953 non-null   object
#  9   gender                5953 non-null   object
#  10  maritalstatus         5953 non-null   object
#  11  territory_country     5953 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(6)
# memory usage: 558.2+ KB

# %%
# ganti type dari numeric menjadi object untuk colom product_id, customer_id
df_new['product_id'] = df_new['product_id'].astype(str)
df_new['customer_id'] = df_new['customer_id'].astype(str)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5953 entries, 0 to 5952
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_detail_id       5953 non-null   object
#  1   order_date            5953 non-null   datetime64[ns]
#  2   product_id            5953 non-null   object
#  3   customer_id           5953 non-null   object
#  4   quantity              5953 non-null   int64
#  5   totalprice_rupiah     5953 non-null   int64
#  6   shippingprice_rupiah  5953 non-null   int64
#  7   product_name          5953 non-null   object
#  8   category              5953 non-null   object
#  9   gender                5953 non-null   object
#  10  maritalstatus         5953 non-null   object
#  11  territory_country     5953 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 558.2+ KB

# %%
# cek duplicate
len(df_new.drop_duplicates()) / len(df_new)
# Out:
# 1.0

# %% [markdown]
# tidak ada duplicate

# %%
# check missing value
print(df_new.isnull().sum())
# Out:
# order_detail_id         0
# order_date              0
# product_id              0
# customer_id             0
# quantity                0
# totalprice_rupiah       0
# shippingprice_rupiah    0
# product_name            0
# category                0
# gender                  0
# maritalstatus           0
# territory_country       0
# dtype: int64

# %% [markdown]
# tidak ada missing value

# %%
def check_plot(df_new, variable):
    # fungsi mengambil kerangka data (df) dan
    # variabel yang diminati sebagai argumen

    # tentukan ukuran gambar
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.histplot(df_new[variable], bins=30)
    plt.title('Histogram')

    # plot Q-Q
    plt.subplot(1, 3, 2)
    stats.probplot(df_new[variable], dist="norm", plot=plt)
    plt.ylabel('Variable quantiles')

    # box plot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df_new[variable])
    plt.title('Boxplot')

    plt.show()

# %%
# lakukan looping untuk melihat plot distribusi data dan outlier pada kolom-kolom
# untuk plot Q-Q
import scipy.stats as stats

# Get numeric columns
numeric_cols = df_new.select_dtypes(include=np.number).columns

for i in numeric_cols:
  print(f"==================== {i} ====================")
  check_plot(df_new, i)
# Out:
# ==================== quantity ====================
# ==================== totalprice_rupiah ====================
# ==================== shippingprice_rupiah ====================

# %% [markdown]
# Tidak ada outlier

# %% [markdown]
# Data sudah bisa digunkaan untuk powerbi
